# %% [markdown]
# # Dataset

# %%
import pandas as pd
import numpy as np
import json

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

import altair as alt
alt.renderers.enable('notebook')
alt.data_transformers.enable('default', max_rows=None)

from utils import *
# %load_ext autoreload
# %autoreload 2

# %%
df = load_json(path='C:/Users/chladek/Documents/github/exponea/exponea_prediction_dummy_data/campaign.json')
df = rem_const(df)
# for easier exploration
df.drop(['recipient','language'],1,inplace=True)

# %%
# timerange
[df.iloc[0,:].date,df.iloc[-1,:].date]
# Out:
# [Timestamp('2018-03-17 07:05:28.764564037'),
#  Timestamp('2018-05-16 06:50:46.329377890')]

# %% [markdown]
# ## Dataset creation

# %%
# https://knowledge.hubspot.com/email-user-guide-v2/understanding-email-deliverability
# query just emails since opened/clicked except for 2 instances (pushweb) are only emails
# ie action_type='split' => status='failed' are out in that case

strng = 'email'
df = df.query("(action_type == @strng)")
df.drop('action_type',1,inplace=True)

# %%
# other statuses shouldn't matter

strng = "delivered"
strng1 = 'opened'
strng2 = 'clicked'
sample = df.query("status == @strng | status == @strng1 | status == @strng2")

# %%
# create unique identifier for customer + campaign
sample['unique_id'] = sample['customer_id'].map(str) + sample['campaign_id']

# %%
# need to drop duplated rows
sample.drop_duplicates(inplace=True)

# %%
# drop clicked to unsubscribe since this is not positive response
sample = sample[~sample['url'].str.contains("unsubscribe",na=False)]

# %%
# prepare df for loop to be in correct order

sample = sample.sort_values(by=['unique_id','date'])
sample.reset_index(inplace=True)

# %%
# tryng to iterate over rows and look if in sorted df
# row below is success given current row is delivered
# if not we consider unsuccess
output = []
val = None
for i, row in sample.iterrows():
    #print(i)
    #print(sample.loc[i,:])
    # only delivered can be opened/clicked
    if (row.status == 'delivered') & (i < len(sample)-1):
        #since we sorted by id & date we row below has to be opened/clicked
        # to be success
        if (sample.loc[i+1,:].status != 'delivered') & (row.unique_id == sample.loc[i+1,:].unique_id):
            val = 1
        else:
            val = 0
    else:
        val = 0
    output.append(val)

# %%
# assign response variable
sample['response'] = output
sample['hour'] = sample.date.dt.hour

# %%
# take just training instances
strng = 'delivered'
df = sample.query('status == @strng')

# %% [markdown]
# ## Create new features

# %% [markdown]
# ##### Purchased item

# %%
# this is more of pipeline for future predictions

# %%
purchased = load_json(path='exponea_prediction_dummy_data/purchase_item.json')
prch = rem_const(purchased)
prch['freq'] = prch.groupby('customer_id')['customer_id'].transform('count')
prch['last'] = prch.groupby('customer_id')['date'].transform('last')
prch.sort_values(by=['customer_id','date'], inplace=True)

# %%
# mean difference in minutes between puchases for each customer
prch['diff'] = prch.groupby(['customer_id'])['date'].transform(lambda x: x.diff().dt.seconds.div(60))
prch['mean_diff'] = prch.groupby('customer_id')['diff'].transform('mean').fillna(0)
prch.drop('diff', 1,inplace=True)

# %% [markdown]
# ##### Cart update

# %%
cart = load_json(path='exponea_prediction_dummy_data/cart_update.json')
cart = rem_const(cart)
cart['freq'] = cart.groupby('customer_id')['customer_id'].transform('count')
cart['last'] = cart.groupby('customer_id')['date'].transform('last')
cart.sort_values(by=['customer_id','date'], inplace=True)

# %%
# mean difference in minutes between cart updates for each customer
cart['diff'] = cart.groupby(['customer_id'])['date'].transform(lambda x: x.diff().dt.seconds.div(60))
cart['mean_diff'] = cart.groupby('customer_id')['diff'].transform('mean').fillna(0)
cart.drop('diff', 1,inplace=True)

# %% [markdown]
# #### Email openings metrics

# %%
# how many unique campaign customer opened and with what mean differences

# %%
strng = 'clicked'
strng1 = 'opened'
sample = sample.query('status == @strng | status ==@strng1')
sample.sort_values(by='date',inplace=True)
email = sample[~sample.duplicated(subset='unique_id')]

# %%
email['freq'] = email.groupby('customer_id')['customer_id'].transform('count')
email['last'] = email.groupby('customer_id')['date'].transform('last')
email.sort_values(by=['customer_id','date'], inplace=True)

# %%
# mean difference in minutes between oepened/clicked emails for each customer 
email['diff'] = email.groupby(['customer_id'])['date'].transform(lambda x: x.diff().dt.seconds.div(60))
email['mean_diff'] = email.groupby('customer_id')['diff'].transform('mean').fillna(0)
email.drop('diff', 1,inplace=True)

# %% [markdown]
# ## Mapping sets of features to each row

# %%
# take delivered email.date load datatsets and recalculate
# for corner cases we will use Naive population model

# %%
# prch
purchased = load_json(path='exponea_prediction_dummy_data/purchase_item.json')
prch = rem_const(purchased)

# cart
cart = load_json(path='exponea_prediction_dummy_data/cart_update.json')
cart = rem_const(cart)

# view
view = load_json(path='exponea_prediction_dummy_data/view_product.json')
view.drop('eans',1,inplace=True)
view = rem_const(view)

# session_start
sess = load_json(path='exponea_prediction_dummy_data/session_start.json')
sess = rem_const(sess)

# %%
# Below takes unreasonably long

prch_feats = []
cart_feats = []
view_feats = []
sess_feats = []
email_feats = []


import time
start = time.time()

for i,row in df.iterrows():
    print(i)
    # for each row create subset that was actual in time of the email
    temp1 = prch[(prch.date < row.date) & (prch.customer_id == row.customer_id)]
    prch_feats.append(add_metrics(temp1))
    
    temp2 = cart[(cart.date < row.date) & (cart.customer_id == row.customer_id)]
    cart_feats.append(add_metrics(temp2))
    
    temp3 = view[(view.date < row.date) & (view.customer_id == row.customer_id)]
    view_feats.append(add_metrics(temp3))
    
    temp4 = sess[(sess.date < row.date) & (sess.customer_id == row.customer_id)]
    sess_feats.append(add_metrics(temp4))
    
    temp5 = email[(email.date < row.date) & (email.customer_id == row.customer_id)]
    email_feats.append(add_metrics(temp5))
    
print(time.time-start)

# %%
a = prch_feats
b = cart_feats
c = view_feats
d = sess_feats
e = email_feats

# %%
# in seconds but probably will need to be updated
dataset['prch_freq'] = list(zip(*a))[0]
dataset['prch_last'] = (dataset.date - pd.to_datetime(list(zip(*a))[1],errors='coerce')).dt.seconds.fillna(0).div(60)
dataset['prch_mean_diff'] = list(zip(*a))[2]

dataset['cart_freq'] = list(zip(*b))[0]
dataset['cart_last'] = (dataset.date - pd.to_datetime(list(zip(*b))[1],errors='coerce')).dt.seconds.fillna(0).div(60)
dataset['cart_mean_diff'] = list(zip(*b))[2]


dataset['view_freq'] = list(zip(*c))[0]
dataset['view_last'] = (dataset.date - pd.to_datetime(list(zip(*c))[1],errors='coerce')).dt.seconds.fillna(0).div(60)
dataset['view_mean_diff'] = list(zip(*c))[2]


dataset['sess_freq'] = list(zip(*d))[0]
dataset['sess_last'] = (dataset.date - pd.to_datetime(list(zip(*d))[1],errors='coerce')).dt.seconds.fillna(0).div(60)
dataset['sess_mean_diff'] = list(zip(*d))[2]


dataset['email_freq'] = list(zip(*e))[0]
dataset['email_last'] = (dataset.date - pd.to_datetime(list(zip(*e))[1],errors='coerce')).dt.seconds.fillna(0).div(60)
dataset['email_mean_diff'] = list(zip(*e))[2]

# %%
dataset.to_csv('df.csv')

# %% [markdown]
# # Bonus Task

# %%
df = load_json(path='C:/Users/chladek/Documents/github/exponea/exponea_prediction_dummy_data/campaign.json')
df = rem_const(df)
# for easier exploration
df.drop(['recipient','language'],1,inplace=True)

# %%
pi = load_json(path='C:/Users/chladek/Documents/github/exponea/exponea_prediction_dummy_data/purchase_item.json')
pi = rem_const(pi)
# for easier exploration
#pi.drop(['recipient','language'],1,inplace=True)
pi['status'] = 'pitem'
pi['action_type'] = 'purchase'

# %%
pd.concat([df,pi])
# Out:
# C:\Users\chladek\AppData\Local\Continuum\anaconda3-64\envs\tf\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   if __name__ == '__main__':
#         action_id                        action_name action_type  attempts  \
# 15666         1.0                                NaN       split       NaN
# 94979         1.0                                NaN       split       NaN
# 173731        2.0                     Send to slack!     webhook       NaN
# 113296        9.0                Bestsellery týždňa!       email       NaN
# 32830         1.0                                NaN       split       NaN
# 113297      589.0                       NL 15.3.2018       email       NaN
# 94774       589.0                       NL 15.3.2018       email       NaN
# 138746        1.0                                NaN       split       NaN
# 113298      585.0                       NL 13.3.2018       email       NaN
# 113299      583.0                       NL 12.3.2018       email       NaN
# 191121        1.0                                NaN       split       NaN
# 71740         2.0                     Send to slack!     webhook       NaN
# 51811         1.0                                NaN       split       NaN
# 158652        2.0                     Send to slack!     webhook       NaN
# 59424         3.0  Najpredávanejšie produkty týždňa!       email       NaN
# 62291         3.0  Najpredávanejšie produkty týždňa!       email       NaN
# 160615      589.0                       NL 15.3.2018       email       NaN
# 63314         1.0                                NaN       split       NaN
# 32831         4.0                    Unnamed webhook     webhook       NaN
# 125437        3.0  Najpredávanejšie produkty týždňa!       email       NaN
# 125438      589.0                       NL 15.3.2018       email       NaN
# 32832         3.0                 voucher po banneri       email       NaN
# 125439      589.0                       NL 15.3.2018       email       NaN
# 95987       589.0                       NL 15.3.2018       email       NaN
# 95988         9.0                Bestsellery týždňa!       email       NaN
# 32833         3.0                 voucher po banneri       email       NaN
# 158653        2.0                     Send to slack!     webhook       NaN
# 136352        2.0                     Send to slack!     webhook       NaN
# 179015        1.0                                NaN       split       NaN
# 139742        1.0                                NaN       split       NaN
# ...           ...                                ...         ...       ...
# 1277          NaN                                NaN    purchase       NaN
# 1276          NaN                                NaN    purchase       NaN
# 384           NaN                                NaN    purchase       NaN
# 1284          NaN                                NaN    purchase       NaN
# 1283          NaN                                NaN    purchase       NaN
# 1282          NaN                                NaN    purchase       NaN
# 2112          NaN                                NaN    purchase       NaN
# 956           NaN                                NaN    purchase       NaN
# 955           NaN                                NaN    purchase       NaN
# 954           NaN                                NaN    purchase       NaN
# 953           NaN                                NaN    purchase       NaN
# 952           NaN                                NaN    purchase       NaN
# 957           NaN                                NaN    purchase       NaN
# 786           NaN                                NaN    purchase       NaN
# 785           NaN                                NaN    purchase       NaN
# 2242          NaN                                NaN    purchase       NaN
# 2520          NaN                                NaN    purchase       NaN
# 2519          NaN                                NaN    purchase       NaN
# 120           NaN                                NaN    purchase       NaN
# 119           NaN                                NaN    purchase       NaN
# 118           NaN                                NaN    purchase       NaN
# 117           NaN                                NaN    purchase       NaN
# 116           NaN                                NaN    purchase       NaN
# 1752          NaN                                NaN    purchase       NaN
# 1751          NaN                                NaN    purchase       NaN
# 1750          NaN                                NaN    purchase       NaN
# 336           NaN                                NaN    purchase       NaN
# 2009          NaN                                NaN    purchase       NaN
# 1427          NaN                                NaN    purchase       NaN
# 1426          NaN                                NaN    purchase       NaN
#
#               browser               campaign_id  \
# 15666             NaN  59fc8338fb600940731935f0
# 94979             NaN  59fc8338fb600940731935f0
# 173731            NaN  58889ab6fb6009af23b672b8
# 113296            NaN  5a8c21394d539b32864d36a3
# 32830             NaN  59fc8338fb600940731935f0
# 113297            NaN  5aa9450bfb600912c10577a8
# 94774             NaN  5aa9450bfb600912c10577a8
# 138746            NaN  59fc8338fb600940731935f0
# 113298            NaN  5aa78163fb60092cb82f9789
# 113299            NaN  5aa62cf9fb60092cb3e86e18
# 191121            NaN  59fc8338fb600940731935f0
# 71740             NaN  58889ab6fb6009af23b672b8
# 51811             NaN  59fc8338fb600940731935f0
# 158652            NaN  58889ab6fb6009af23b672b8
# 59424             NaN  5a8c21394d539b32864d36a3
# 62291             NaN  5a8c21394d539b32864d36a3
# 160615            NaN  5aa9450bfb600912c10577a8
# 63314             NaN  59fc8338fb600940731935f0
# 32831             NaN  58c6cebbfb600944086bd1da
# 125437            NaN  5a8c21394d539b32864d36a3
# 125438            NaN  5aa9450bfb600912c10577a8
# 32832             NaN  58c6cebbfb600944086bd1da
# 125439            NaN  5aa9450bfb600912c10577a8
# 95987             NaN  5aa9450bfb600912c10577a8
# 95988             NaN  5a8c21394d539b32864d36a3
# 32833             NaN  58c6cebbfb600944086bd1da
# 158653            NaN  58889ab6fb6009af23b672b8
# 136352            NaN  58889ab6fb6009af23b672b8
# 179015            NaN  59fc8338fb600940731935f0
# 139742            NaN  59fc8338fb600940731935f0
# ...               ...                       ...
# 1277           Chrome                       NaN
# 1276           Chrome                       NaN
# 384     Mobile Safari                       NaN
# 1284           Chrome                       NaN
# 1283           Chrome                       NaN
# 1282           Chrome                       NaN
# 2112           Chrome                       NaN
# 956            Chrome                       NaN
# 955            Chrome                       NaN
# 954            Chrome                       NaN
# 953            Chrome                       NaN
# 952            Chrome                       NaN
# 957           Mozilla                       NaN
# 786            Chrome                       NaN
# 785            Chrome                       NaN
# 2242           Chrome                       NaN
# 2520           Chrome                       NaN
# 2519           Chrome                       NaN
# 120            Chrome                       NaN
# 119            Chrome                       NaN
# 118            Chrome                       NaN
# 117            Chrome                       NaN
# 116            Chrome                       NaN
# 1752           Chrome                       NaN
# 1751           Chrome                       NaN
# 1750           Chrome                       NaN
# 336            Chrome                       NaN
# 2009           Chrome                       NaN
# 1427           Chrome                       NaN
# 1426           Chrome                       NaN
#
#                           campaign_name campaign_policy code  \
# 15666              assign global_tester             NaN  NaN
# 94979              assign global_tester             NaN  NaN
# 173731                    View products                  NaN
# 113296              Bestseller scenario         Default  NaN
# 32830              assign global_tester             NaN  NaN
# 113297             campaign 15.3.2017           Default  NaN
# 94774              campaign 15.3.2017           Default  NaN
# 138746             assign global_tester             NaN  NaN
# 113298              campaign 13.3.2017          Default  NaN
# 113299              campaign 12.3.2017          Default  NaN
# 191121             assign global_tester             NaN  NaN
# 71740                     View products                  NaN
# 51811              assign global_tester             NaN  NaN
# 158652                    View products                  NaN
# 59424               Bestseller scenario         Default  NaN
# 62291               Bestseller scenario         Default  NaN
# 160615             campaign 15.3.2017           Default  NaN
# 63314              assign global_tester             NaN  NaN
# 32831   voucher after purchase [banner]                  NaN
# 125437              Bestseller scenario         Default  NaN
# 125438             campaign 15.3.2017           Default  NaN
# 32832   voucher after purchase [banner]         voucher  NaN
# 125439             campaign 15.3.2017           Default  NaN
# 95987              campaign 15.3.2017           Default  NaN
# 95988               Bestseller scenario         Default  NaN
# 32833   voucher after purchase [banner]         voucher  NaN
# 158653                    View products                  NaN
# 136352                    View products                  NaN
# 179015             assign global_tester             NaN  NaN
# 139742             assign global_tester             NaN  NaN
# ...                                 ...             ...  ...
# 1277                                NaN             NaN  NaN
# 1276                                NaN             NaN  NaN
# 384                                 NaN             NaN  NaN
# 1284                                NaN             NaN  NaN
# 1283                                NaN             NaN  NaN
# 1282                                NaN             NaN  NaN
# 2112                                NaN             NaN  NaN
# 956                                 NaN             NaN  NaN
# 955                                 NaN             NaN  NaN
# 954                                 NaN             NaN  NaN
# 953                                 NaN             NaN  NaN
# 952                                 NaN             NaN  NaN
# 957                                 NaN             NaN  NaN
# 786                                 NaN             NaN  NaN
# 785                                 NaN             NaN  NaN
# 2242                                NaN             NaN  NaN
# 2520                                NaN             NaN  NaN
# 2519                                NaN             NaN  NaN
# 120                                 NaN             NaN  NaN
# 119                                 NaN             NaN  NaN
# 118                                 NaN             NaN  NaN
# 117                                 NaN             NaN  NaN
# 116                                 NaN             NaN  NaN
# 1752                                NaN             NaN  NaN
# 1751                                NaN             NaN  NaN
# 1750                                NaN             NaN  NaN
# 336                                 NaN             NaN  NaN
# 2009                                NaN             NaN  NaN
# 1427                                NaN             NaN  NaN
# 1426                                NaN             NaN  NaN
#
#                      customer_id   ...   new_choice       os platform  \
# 15666   0900e28352e997db314a71ea   ...         True      NaN      NaN
# 94979   789ed10c5514ed056b4a775c   ...         True      NaN      NaN
# 173731  ddde844ca53d11d5b2abfa2a   ...          NaN      NaN      NaN
# 113296  2d2fd9d9b1a0cab84795816d   ...          NaN      NaN      NaN
# 32830   89e51d1245cd95432aa0517f   ...         True      NaN      NaN
# 113297  2d2fd9d9b1a0cab84795816d   ...          NaN      NaN      NaN
# 94774   1860514b89ffd3535472ff5e   ...          NaN      NaN      NaN
# 138746  23da507804c47d5366226c0f   ...         True      NaN      NaN
# 113298  2d2fd9d9b1a0cab84795816d   ...          NaN      NaN      NaN
# 113299  2d2fd9d9b1a0cab84795816d   ...          NaN      NaN      NaN
# 191121  9441a2b36e849990afb2fe3e   ...         True      NaN      NaN
# 71740   59df34d195b17f28b6ac81fb   ...          NaN      NaN      NaN
# 51811   bb6e86fc9923f7bf64e42a11   ...         True      NaN      NaN
# 158652  6803e66100e50af4f22df48e   ...          NaN      NaN      NaN
# 59424   698c8fb11aff41a1bca4d723   ...          NaN      NaN      NaN
# 62291   82cbbf0163e4f9d74a8e3028   ...          NaN      NaN      NaN
# 160615  f0dc64ffe061878afcfa8ce3   ...          NaN      NaN      NaN
# 63314   899c170b59378d132364e42d   ...         True      NaN      NaN
# 32831   89e51d1245cd95432aa0517f   ...          NaN      NaN      NaN
# 125437  cec1892d88fdf9099a9ed726   ...          NaN      NaN      NaN
# 125438  cec1892d88fdf9099a9ed726   ...          NaN      NaN      NaN
# 32832   89e51d1245cd95432aa0517f   ...          NaN      NaN      NaN
# 125439  cec1892d88fdf9099a9ed726   ...          NaN      NaN      NaN
# 95987   5d8f772b41f3248c7253dd7d   ...          NaN      NaN      NaN
# 95988   5d8f772b41f3248c7253dd7d   ...          NaN      NaN      NaN
# 32833   89e51d1245cd95432aa0517f   ...          NaN      NaN      NaN
# 158653  6803e66100e50af4f22df48e   ...          NaN      NaN      NaN
# 136352  9276faa155cf7214c95f67d5   ...          NaN      NaN      NaN
# 179015  a6a4533e78122816d20b7df9   ...         True      NaN      NaN
# 139742  27f390095247cd4f54b5eb41   ...         True      NaN      NaN
# ...                          ...   ...          ...      ...      ...
# 1277    0ca2e226135f9655524a20e7   ...          NaN  Windows      NaN
# 1276    0ca2e226135f9655524a20e7   ...          NaN  Windows      NaN
# 384     3cbd5596b01cbad592afd30d   ...          NaN      iOS      NaN
# 1284    0be8db7696c2af08347dc5f8   ...          NaN  Windows      NaN
# 1283    0be8db7696c2af08347dc5f8   ...          NaN  Windows      NaN
# 1282    0be8db7696c2af08347dc5f8   ...          NaN  Windows      NaN
# 2112    f56169875b1ef6ec451ee622   ...          NaN  Android      NaN
# 956     05917886cf0ac4bea0e06688   ...          NaN  Windows      NaN
# 955     05917886cf0ac4bea0e06688   ...          NaN  Windows      NaN
# 954     05917886cf0ac4bea0e06688   ...          NaN  Windows      NaN
# 953     05917886cf0ac4bea0e06688   ...          NaN  Windows      NaN
# 952     05917886cf0ac4bea0e06688   ...          NaN  Windows      NaN
# 957     ed587428342e200bd3f0c3bf   ...          NaN  Windows      NaN
# 786     d5ebfd8856e93b016909b74e   ...          NaN  Android      NaN
# 785     d5ebfd8856e93b016909b74e   ...          NaN  Android      NaN
# 2242    12568b4258cebe52e9febaa4   ...          NaN  Windows      NaN
# 2520    15f82c5d3889633c20ee32c5   ...          NaN  Android      NaN
# 2519    15f82c5d3889633c20ee32c5   ...          NaN  Android      NaN
# 120     593df81da6dba3e104ec8b6d   ...          NaN  Windows      NaN
# 119     593df81da6dba3e104ec8b6d   ...          NaN  Windows      NaN
# 118     593df81da6dba3e104ec8b6d   ...          NaN  Windows      NaN
# 117     593df81da6dba3e104ec8b6d   ...          NaN  Windows      NaN
# 116     593df81da6dba3e104ec8b6d   ...          NaN  Windows      NaN
# 1752    fb5548a2c7084d8343251d8c   ...          NaN  Android      NaN
# 1751    fb5548a2c7084d8343251d8c   ...          NaN  Android      NaN
# 1750    fb5548a2c7084d8343251d8c   ...          NaN  Android      NaN
# 336     55acd47d8aea90deca3a3d0e   ...          NaN  Windows      NaN
# 2009    e409d4516f866cf96b284867   ...          NaN  Android      NaN
# 1427    06107991e332c8ae1b025702   ...          NaN  Android      NaN
# 1426    06107991e332c8ae1b025702   ...          NaN  Android      NaN
#
#        product_id     status status_code  \
# 15666         NaN        NaN         NaN
# 94979         NaN        NaN         NaN
# 173731        NaN     failed       404.0
# 113296        NaN     opened         NaN
# 32830         NaN        NaN         NaN
# 113297        NaN     opened         NaN
# 94774         NaN     opened         NaN
# 138746        NaN        NaN         NaN
# 113298        NaN     opened         NaN
# 113299        NaN     opened         NaN
# 191121        NaN        NaN         NaN
# 71740         NaN     failed       404.0
# 51811         NaN        NaN         NaN
# 158652        NaN     failed       404.0
# 59424         NaN     opened         NaN
# 62291         NaN     opened         NaN
# 160615        NaN     opened         NaN
# 63314         NaN        NaN         NaN
# 32831         NaN       sent       200.0
# 125437        NaN     opened         NaN
# 125438        NaN     opened         NaN
# 32832         NaN   enqueued         NaN
# 125439        NaN    clicked         NaN
# 95987         NaN     opened         NaN
# 95988         NaN     opened         NaN
# 32833         NaN  delivered         NaN
# 158653        NaN     failed       404.0
# 136352        NaN     failed       404.0
# 179015        NaN        NaN         NaN
# 139742        NaN        NaN         NaN
# ...           ...        ...         ...
# 1277       562833      pitem         NaN
# 1276       652827      pitem         NaN
# 384        613173      pitem         NaN
# 1284       610569      pitem         NaN
# 1283       620873      pitem         NaN
# 1282       621397      pitem         NaN
# 2112       672391      pitem         NaN
# 956          6417      pitem         NaN
# 955        634151      pitem         NaN
# 954        634153      pitem         NaN
# 953        107521      pitem         NaN
# 952        107355      pitem         NaN
# 957         34498      pitem         NaN
# 786        614229      pitem         NaN
# 785        687255      pitem         NaN
# 2242       674305      pitem         NaN
# 2520       610567      pitem         NaN
# 2519       621361      pitem         NaN
# 120         37564      pitem         NaN
# 119         37565      pitem         NaN
# 118        555769      pitem         NaN
# 117        667327      pitem         NaN
# 116        670909      pitem         NaN
# 1752       346405      pitem         NaN
# 1751       352633      pitem         NaN
# 1750       390037      pitem         NaN
# 336          8359      pitem         NaN
# 2009       352633      pitem         NaN
# 1427       610561      pitem         NaN
# 1426       670483      pitem         NaN
#
#                                                       url  \
# 15666                                                 NaN
# 94979                                                 NaN
# 173731                                                NaN
# 113296                                                NaN
# 32830                                                 NaN
# 113297                                                NaN
# 94774                                                 NaN
# 138746                                                NaN
# 113298                                                NaN
# 113299                                                NaN
# 191121                                                NaN
# 71740                                                 NaN
# 51811                                                 NaN
# 158652                                                NaN
# 59424                                                 NaN
# 62291                                                 NaN
# 160615                                                NaN
# 63314                                                 NaN
# 32831                                                 NaN
# 125437                                                NaN
# 125438                                                NaN
# 32832                                                 NaN
# 125439  /kangol-clsc-hrington-s81-60508390?utm_source=...
# 95987                                                 NaN
# 95988                                                 NaN
# 32833                                                 NaN
# 158653                                                NaN
# 136352                                                NaN
# 179015                                                NaN
# 139742                                                NaN
# ...                                                   ...
# 1277                                                  NaN
# 1276                                                  NaN
# 384                                                   NaN
# 1284                                                  NaN
# 1283                                                  NaN
# 1282                                                  NaN
# 2112                                                  NaN
# 956                                                   NaN
# 955                                                   NaN
# 954                                                   NaN
# 953                                                   NaN
# 952                                                   NaN
# 957                                                   NaN
# 786                                                   NaN
# 785                                                   NaN
# 2242                                                  NaN
# 2520                                                  NaN
# 2519                                                  NaN
# 120                                                   NaN
# 119                                                   NaN
# 118                                                   NaN
# 117                                                   NaN
# 116                                                   NaN
# 1752                                                  NaN
# 1751                                                  NaN
# 1750                                                  NaN
# 336                                                   NaN
# 2009                                                  NaN
# 1427                                                  NaN
# 1426                                                  NaN
#
#                                                user-agent    variant weekday
# 15666                                                 NaN  Variant A       6
# 94979                                                 NaN  Variant A       6
# 173731                                                NaN        NaN       6
# 113296  Mozilla/5.0 (Windows NT 5.1; rv:11.0) Gecko Fi...        NaN       6
# 32830                                                 NaN  Variant A       6
# 113297  Mozilla/5.0 (Windows NT 5.1; rv:11.0) Gecko Fi...        NaN       6
# 94774   Mozilla/5.0 (Windows NT 5.1; rv:11.0) Gecko Fi...        NaN       6
# 138746                                                NaN  Variant A       6
# 113298  Mozilla/5.0 (Windows NT 5.1; rv:11.0) Gecko Fi...        NaN       6
# 113299  Mozilla/5.0 (Windows NT 5.1; rv:11.0) Gecko Fi...        NaN       6
# 191121                                                NaN  Variant A       6
# 71740                                                 NaN        NaN       6
# 51811                                                 NaN  Variant A       6
# 158652                                                NaN        NaN       6
# 59424   Mozilla/5.0 (Windows NT 5.1; rv:11.0) Gecko Fi...        NaN       6
# 62291   Mozilla/5.0 (Linux; Android 6.0.1; SM-G900F Bu...        NaN       6
# 160615  Mozilla/5.0 (Windows NT 5.1; rv:11.0) Gecko Fi...        NaN       6
# 63314                                                 NaN  Variant A       6
# 32831                                                 NaN        NaN       6
# 125437  Mozilla/5.0 (iPad; CPU OS 11_2_5 like Mac OS X...        NaN       6
# 125438  Mozilla/5.0 (iPad; CPU OS 11_2_5 like Mac OS X...        NaN       6
# 32832                                                 NaN        NaN       6
# 125439  Mozilla/5.0 (iPad; CPU OS 11_2_5 like Mac OS X...        NaN       6
# 95987   Mozilla/5.0 (Windows NT 5.1; rv:11.0) Gecko Fi...        NaN       6
# 95988   Mozilla/5.0 (Windows NT 5.1; rv:11.0) Gecko Fi...        NaN       6
# 32833                                                 NaN        NaN       6
# 158653                                                NaN        NaN       6
# 136352                                                NaN        NaN       6
# 179015                                                NaN  Variant A       6
# 139742                                                NaN  Variant A       6
# ...                                                   ...        ...     ...
# 1277                                                  NaN        NaN       2
# 1276                                                  NaN        NaN       2
# 384                                                   NaN        NaN       2
# 1284                                                  NaN        NaN       2
# 1283                                                  NaN        NaN       2
# 1282                                                  NaN        NaN       2
# 2112                                                  NaN        NaN       2
# 956                                                   NaN        NaN       2
# 955                                                   NaN        NaN       2
# 954                                                   NaN        NaN       2
# 953                                                   NaN        NaN       2
# 952                                                   NaN        NaN       2
# 957                                                   NaN        NaN       2
# 786                                                   NaN        NaN       2
# 785                                                   NaN        NaN       2
# 2242                                                  NaN        NaN       2
# 2520                                                  NaN        NaN       2
# 2519                                                  NaN        NaN       2
# 120                                                   NaN        NaN       2
# 119                                                   NaN        NaN       2
# 118                                                   NaN        NaN       2
# 117                                                   NaN        NaN       2
# 116                                                   NaN        NaN       2
# 1752                                                  NaN        NaN       2
# 1751                                                  NaN        NaN       2
# 1750                                                  NaN        NaN       2
# 336                                                   NaN        NaN       2
# 2009                                                  NaN        NaN       2
# 1427                                                  NaN        NaN       3
# 1426                                                  NaN        NaN       3
#
# [194714 rows x 27 columns]
